# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
da=pd.read_csv("F:\\Desktop\\statistics\\stats 1\\utf-8''nhanes_2015_2016.csv")

# %%
sns.regplot(x=da['BMXLEG'],y=da['BMXARML'], fit_reg=False, scatter_kws={"alpha": 0.2})
#regplot for scatterplot

# %%
sns.jointplot(x=da['BMXLEG'],y=da['BMXARML'],kind='kde')

# %%
sns.jointplot(x=da['BPXSY1'],y=da['BPXDI1'],kind='kde')

# %%
da['RIAGENDR'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    2
# Name: RIAGENDR, dtype: int64

# %%
da['RIAGENDRx']=da.RIAGENDR.replace({1:'Male',2:'Female'})
sns.FacetGrid(da,col='RIAGENDRx').map(plt.scatter,'BMXLEG','BMXARML',alpha=0.4).add_legend()

# %%
a=sns.boxplot(da.DMDMARTL,da.RIDAGEYR)
a
