# %%
import pandas as pd
import nltk
import numpy as np
import string
from sklearn.metrics  import confusion_matrix,f1_score

# %% [markdown]
# ### reading files

# %%
with open('../data/edgar_allan_poe.txt','r') as f:
    lines_edgar = f.read().splitlines()
    lines_edgar 

with open('../data/robert_frost.txt','r') as f:
    lines_frost = f.read().splitlines()

# %%
lines_edgar[:5]
# Out:
# ["LO! Death hath rear'd himself a throne",
#  'In a strange city, all alone,',
#  'Far down within the dim west',
#  'Where the good, and the bad, and the worst, and the best,',
#  'Have gone to their eternal rest.']

# %%
lines_frost[:5]
# Out:
# ['Two roads diverged in a yellow wood,',
#  'And sorry I could not travel both',
#  'And be one traveler, long I stood',
#  'And looked down one as far as I could',
#  'To where it bent in the undergrowth; ']

# %%
len(lines_edgar)
# Out:
# 797

# %%
len(lines_frost)
# Out:
# 1581

# %%
df = pd.concat([pd.DataFrame({'lines':lines_edgar,'label':'poe'}),pd.DataFrame({'lines':lines_frost,'label':'frost'})])

# %%
df.lines = df.lines.apply(lambda x:x.lower())
df.lines = df.lines.apply(lambda x:x.strip())

# %%
df = df[df.lines!='']
df
# Out:
#                                                   lines  label
# 0                lo! death hath rear'd himself a throne    poe
# 1                         in a strange city, all alone,    poe
# 2                          far down within the dim west    poe
# 3     where the good, and the bad, and the worst, an...    poe
# 4                      have gone to their eternal rest.    poe
# ...                                                 ...    ...
# 1575    to say which buds are leaf and which are bloom.  frost
# 1577             a feather-hammer gives a double knock.  frost
# 1578              this eden day is done at two o'clock.  frost
# 1579         an hour of winter day might seem too short  frost
# 1580   to make it worth life's while to wake and sport.  frost
#
# [2154 rows x 2 columns]

# %%
df.reset_index(inplace=True,drop=True)
df
# Out:
#                                                   lines  label
# 0                lo! death hath rear'd himself a throne    poe
# 1                         in a strange city, all alone,    poe
# 2                          far down within the dim west    poe
# 3     where the good, and the bad, and the worst, an...    poe
# 4                      have gone to their eternal rest.    poe
# ...                                                 ...    ...
# 2149    to say which buds are leaf and which are bloom.  frost
# 2150             a feather-hammer gives a double knock.  frost
# 2151              this eden day is done at two o'clock.  frost
# 2152         an hour of winter day might seem too short  frost
# 2153   to make it worth life's while to wake and sport.  frost
#
# [2154 rows x 2 columns]

# %% [markdown]
# ### train test split

# %%
df_train = df.sample(frac=0.75)
df_test = df.drop(df_train.index)
df_test = df_test.sample(frac=1)

# %%
df_train
# Out:
#                                                 lines  label
# 198         for the resurrection of deep-buried faith    poe
# 1853                           still more unfettered,  frost
# 184                    be nothing which thou art not.    poe
# 1800                and in it a piano loudly playing.  frost
# 1328   then he came at me with one hand outstretched,  frost
# ...                                               ...    ...
# 264                               from their throats.    poe
# 1034  up where the trees grow short, the mosses tall,  frost
# 1863                                 the cosmic motes  frost
# 1895         but being mounted bareback on the earth?  frost
# 629              in beauty by our god, to those alone    poe
#
# [1616 rows x 2 columns]

# %%
df_test
# Out:
#                                                   lines  label
# 1473      she made a sudden movement toward her bodice,  frost
# 1945              to live together and then pull apart.  frost
# 951                 of arthur amy's having once been up  frost
# 532           (though once we had journeyed down here),    poe
# 201             lying down to die, have suddenly arisen    poe
# ...                                                 ...    ...
# 878                     but though repeatedly he strove  frost
# 514              in the ghoul-haunted woodland of weir.    poe
# 534             nor the ghoul-haunted woodland of weir.    poe
# 329   could hope to utter. and i! my spells are broken.    poe
# 1784            to watch me and see what i came to get.  frost
#
# [538 rows x 2 columns]

# %% [markdown]
# ### creating the markov model for each class

# %%
df_train.reset_index(inplace=True, drop=True)

# %% [markdown]
# #### STEP 1 - tokenize each sentence of the poem

# %%
df_train['lines_tokenized'] = df_train.lines.apply(nltk.word_tokenize)

# %%
df_train.lines_tokenized = df_train.lines_tokenized.apply(lambda x:[i for i in x if i not in string.punctuation])

# %%
df_train.head()
# Out:
#                                             lines  label  \
# 0       for the resurrection of deep-buried faith    poe
# 1                          still more unfettered,  frost
# 2                  be nothing which thou art not.    poe
# 3               and in it a piano loudly playing.  frost
# 4  then he came at me with one hand outstretched,  frost
#
#                                      lines_tokenized
# 0   [for, the, resurrection, of, deep-buried, faith]
# 1                          [still, more, unfettered]
# 2               [be, nothing, which, thou, art, not]
# 3           [and, in, it, a, piano, loudly, playing]
# 4  [then, he, came, at, me, with, one, hand, outs...

# %% [markdown]
# #### STEP 2 - create token to integer mapping for each unique token

# %%
token_to_num_mapping = {}
count=0
for i,row in df_train.iterrows():
    for j in row['lines_tokenized']:
        if j not in token_to_num_mapping:
            token_to_num_mapping[j] = count
            count+=1

# %%
len(token_to_num_mapping)
# Out:
# 2608

# %%
def token_num(x):
    x_num = []
    for i in x:
        x_num.append(token_to_num_mapping.get(i,len(token_to_num_mapping)+1))
    return x_num

# %%
df_train['lines_tokenized_num'] = df_train.lines_tokenized.apply(token_num)

# %%
df_train.head()
# Out:
#                                             lines  label  \
# 0       for the resurrection of deep-buried faith    poe
# 1                          still more unfettered,  frost
# 2                  be nothing which thou art not.    poe
# 3               and in it a piano loudly playing.  frost
# 4  then he came at me with one hand outstretched,  frost
#
#                                      lines_tokenized  \
# 0   [for, the, resurrection, of, deep-buried, faith]
# 1                          [still, more, unfettered]
# 2               [be, nothing, which, thou, art, not]
# 3           [and, in, it, a, piano, loudly, playing]
# 4  [then, he, came, at, me, with, one, hand, outs...
#
#                     lines_tokenized_num
# 0                    [0, 1, 2, 3, 4, 5]
# 1                             [6, 7, 8]
# 2               [9, 10, 11, 12, 13, 14]
# 3          [15, 16, 17, 18, 19, 20, 21]
# 4  [22, 23, 24, 25, 26, 27, 28, 29, 30]

# %% [markdown]
# #### separating each model data because each model will have it's own set of data

# %%
df_train_poe = df_train[df_train.label=='poe']
df_train_frost = df_train[df_train.label=='frost']

# %%
df_train_poe.head()
# Out:
#                                        lines label  \
# 0  for the resurrection of deep-buried faith   poe
# 2             be nothing which thou art not.   poe
# 5           and when, amid no earthly moans,   poe
# 6                         which were seven,)   poe
# 8    the truest- the most fervently devoted,   poe
#
#                                     lines_tokenized       lines_tokenized_num
# 0  [for, the, resurrection, of, deep-buried, faith]        [0, 1, 2, 3, 4, 5]
# 2              [be, nothing, which, thou, art, not]   [9, 10, 11, 12, 13, 14]
# 5             [and, when, amid, no, earthly, moans]  [15, 31, 32, 33, 34, 35]
# 6                              [which, were, seven]              [11, 36, 37]
# 8     [the, truest-, the, most, fervently, devoted]    [1, 43, 1, 44, 45, 46]

# %%
df_train_frost.head()
# Out:
#                                             lines  label  \
# 1                          still more unfettered,  frost
# 3               and in it a piano loudly playing.  frost
# 4  then he came at me with one hand outstretched,  frost
# 7          because it was grassy and wanted wear,  frost
# 9                              from sleeping warm  frost
#
#                                      lines_tokenized  \
# 1                          [still, more, unfettered]
# 3           [and, in, it, a, piano, loudly, playing]
# 4  [then, he, came, at, me, with, one, hand, outs...
# 7      [because, it, was, grassy, and, wanted, wear]
# 9                             [from, sleeping, warm]
#
#                     lines_tokenized_num
# 1                             [6, 7, 8]
# 3          [15, 16, 17, 18, 19, 20, 21]
# 4  [22, 23, 24, 25, 26, 27, 28, 29, 30]
# 7          [38, 17, 39, 40, 15, 41, 42]
# 9                          [47, 48, 49]

# %% [markdown]
# ####

# %% [markdown]
# ### fitting the markov model

# %% [markdown]
# #### pi & A -> matrix of transition probalities

# %%
token_to_num_mapping
# Out:
# {'for': 0,
#  'the': 1,
#  'resurrection': 2,
#  'of': 3,
#  'deep-buried': 4,
#  'faith': 5,
#  'still': 6,
#  'more': 7,
#  'unfettered': 8,
#  'be': 9,
#  'nothing': 10,
#  'which': 11,
#  'thou': 12,
#  'art': 13,
#  'not': 14,
#  'and': 15,
#  'in': 16,
#  'it': 17,
#  'a': 18,
#  'piano': 19,
#  'loudly': 20,
#  'playing': 21,
#  'then': 22,
#  'he': 23,
#  'came': 24,
#  'at': 25,
#  'me': 26,
#  'with': 27,
#  'one': 28,
#  'hand': 29,
#  'outstretched': 30,
#  'when': 31,
#  'amid': 32,
#  'no': 33,
#  'earthly': 34,
#  'moans': 35,
#  'were': 36,
#  'seven': 37,
#  'because': 38,
#  'was': 39,
#  'grassy': 40,
#  'wanted': 41,
#  'wear': 42,
#  'truest-': 43,
#  'most': 44,
#  'fervently': 45,
#  'devoted': 46,
#  'from': 47,
#  'sleeping': 48,
#  'warm': 49,
#  'walls': 50,
#  'all': 51,
#  'buried': 52,
#  'trees': 53,
#  'few': 54,
#  'out': 55,
#  'miraculous': 56,
#  'crescent': 57,
#  'henceforth': 58,
#  'i': 59,
#  'hold': 60,
#  'thy': 61,
#  'flower-enameled': 62,
#  'shore': 63,
#  'speculation': 64,
#  'sovereignty': 65,
#  'than': 66,
#  'ancient': 67,
#  'lore': 68,
#  'young': 69,
#  'folk': 70,
#  'held': 71,
#  'some': 72,
#  'hope': 73,
#  'to': 74,
#  'each': 75,
#  'other': 76,
#  'but': 77,
#  'we': 78,
#  'get': 79,
#  'on': 80,
#  'sacred': 81,
#  'sun-': 82,
#  'who': 83,
#  'weeping': 84,
#  'bless': 85,
#  'thee': 86,
#  'ah': 87,
#  'night': 88,
#  'nights': 89,
#  'year': 90,
#  "'d": 91,
#  'say': 92,
#  'she': 93,
#  'does': 94,
#  'likes': 95,
#  'doth': 96,
#  "o'er": 97,
#  'us': 98,
#  'pass': 99,
#  'as': 100,
#  'th': 101,
#  'expanding': 102,
#  'eye': 103,
#  'right': 104,
#  'out-': 105,
#  'matter': 106,
#  'her': 107,
#  'mother': 108,
#  'holy': 109,
#  'rays': 110,
#  'heaven': 111,
#  'come': 112,
#  'down': 113,
#  "'re": 114,
#  'allowed': 115,
#  'take': 116,
#  'them': 117,
#  'upside': 118,
#  'ca': 119,
#  "n't": 120,
#  'talk': 121,
#  'lord': 122,
#  'if': 123,
#  'could': 124,
#  'across': 125,
#  'side': 126,
#  'by': 127,
#  'they': 128,
#  'lay': 129,
#  'an': 130,
#  'unimpassioned': 131,
#  'song': 132,
#  'wearing': 133,
#  'its': 134,
#  'own': 135,
#  'deep': 136,
#  'feeling': 137,
#  'crown': 138,
#  'you': 139,
#  'said': 140,
#  'knew': 141,
#  'place': 142,
#  'where': 143,
#  'once': 144,
#  'kinsman': 145,
#  "'oho": 146,
#  'oho': 147,
#  "'do": 148,
#  'donkey': 149,
#  "'s": 150,
#  'ears': 151,
#  'suggest': 152,
#  'shake': 153,
#  'our': 154,
#  'confusion': 155,
#  'aglitter': 156,
#  'mortal': 157,
#  'melody': 158,
#  "'where": 159,
#  'shall': 160,
#  'meet': 161,
#  'again': 162,
#  'is': 163,
#  'wasted': 164,
#  'like': 165,
#  'snow': 166,
#  'sweet': 167,
#  'flowers': 168,
#  'ere': 169,
#  'long': 170,
#  'safely': 171,
#  'may': 172,
#  'trust': 173,
#  'gleaming': 174,
#  'studying': 175,
#  'genealogy': 176,
#  'will': 177,
#  'half': 178,
#  'believe': 179,
#  'that': 180,
#  'wild': 181,
#  'light': 182,
#  'fraught': 183,
#  'their': 184,
#  'arthur': 185,
#  'amy': 186,
#  'father': 187,
#  'mine': 188,
#  'those': 189,
#  'unusual': 190,
#  'strings': 191,
#  'saw': 192,
#  'window': 193,
#  'black': 194,
#  'even': 195,
#  'lonely': 196,
#  'rose': 197,
#  'lip-begotten': 198,
#  'words-': 199,
#  'helping': 200,
#  'cruel': 201,
#  'him': 202,
#  'rapid': 203,
#  'pleiads': 204,
#  'venuses': 205,
#  'unextinguished': 206,
#  'sun': 207,
#  'cellar': 208,
#  'windows': 209,
#  'banked': 210,
#  'up': 211,
#  'sawdust': 212,
#  'door': 213,
#  'this': 214,
#  'legended': 215,
#  'tomb': 216,
#  "''": 217,
#  'upon': 218,
#  'his': 219,
#  'longer': 220,
#  'axis': 221,
#  'meaning': 222,
#  'soft-murmured': 223,
#  'words': 224,
#  "'let": 225,
#  'there': 226,
#  'used': 227,
#  'live': 228,
#  'here': 229,
#  'robinsons': 230,
#  'expense': 231,
#  'though': 232,
#  'reach': 233,
#  'utmost': 234,
#  'star': 235,
#  'good': 236,
#  'home': 237,
#  'do': 238,
#  'ask': 239,
#  'better': 240,
#  'likely': 241,
#  'regard': 242,
#  'o': 243,
#  'god': 244,
#  'my': 245,
#  'funereal': 246,
#  'mind': 247,
#  'hours': 248,
#  'daylight': 249,
#  'gather': 250,
#  'atmosphere': 251,
#  'hourly': 252,
#  'hope-': 253,
#  'life-': 254,
#  'above': 255,
#  'misty': 256,
#  'mid': 257,
#  'region': 258,
#  'weir-': 259,
#  'john': 260,
#  'too': 261,
#  'old': 262,
#  'have': 263,
#  'grandchildren': 264,
#  'tried': 265,
#  'improve': 266,
#  'sailing': 267,
#  'tile': 268,
#  'brought': 269,
#  'back': 270,
#  'into': 271,
#  'name': 272,
#  "'quick": 273,
#  'slammed': 274,
#  'knob': 275,
#  'only': 276,
#  'farm': 277,
#  'far': 278,
#  'away': 279,
#  'call': 280,
#  'nausicaa': 281,
#  'timber': 282,
#  "'it": 283,
#  'makes': 284,
#  'worse': 285,
#  'must': 286,
#  'blind': 287,
#  'love': 288,
#  'luminous': 289,
#  'eyes': 290,
#  'see': 291,
#  'stopping': 292,
#  'bring': 293,
#  'broad-board': 294,
#  'paneling': 295,
#  'stock': 296,
#  'what': 297,
#  'counts': 298,
#  'ideals': 299,
#  'ridgely': 300,
#  'torrence': 301,
#  'sometimes': 302,
#  'wander': 303,
#  'beaten': 304,
#  'ways': 305,
#  'lo': 306,
#  'death': 307,
#  'hath': 308,
#  'rear': 309,
#  'himself': 310,
#  'throne': 311,
#  'houri': 312,
#  'glances': 313,
#  'are': 314,
#  "'you": 315,
#  'poor': 316,
#  'dear': 317,
#  'great': 318,
#  'granny': 319,
#  'heed': 320,
#  'desolate': 321,
#  'grass-': 322,
#  'thrive': 323,
#  'left': 324,
#  'hopes': 325,
#  'since': 326,
#  'stopped': 327,
#  'lavas': 328,
#  'restlessly': 329,
#  'roll': 330,
#  'should': 331,
#  'feel': 332,
#  'easier': 333,
#  'wishing': 334,
#  'make': 335,
#  'position': 336,
#  'stronger': 337,
#  'think': 338,
#  'find': 339,
#  'hurt': 340,
#  'poem': 341,
#  'rather': 342,
#  'tip': 343,
#  'table': 344,
#  'let': 345,
#  'dangle': 346,
#  'feet': 347,
#  'among': 348,
#  'raspberry': 349,
#  'vines': 350,
#  'had': 351,
#  'vision': 352,
#  'put': 353,
#  'together': 354,
#  'bow': 355,
#  'enough': 356,
#  'mean': 357,
#  'estelle': 358,
#  'has': 359,
#  'always': 360,
#  'purse': 361,
#  'pretend': 362,
#  'tell': 363,
#  'way': 364,
#  'done': 365,
#  'any': 366,
#  'thing': 367,
#  'ours': 368,
#  'ten': 369,
#  "o'clock": 370,
#  'winter': 371,
#  'eve': 372,
#  'fell': 373,
#  'made': 374,
#  'lantern': 375,
#  'rattle': 376,
#  'waiting': 377,
#  'things': 378,
#  'happen': 379,
#  'favour': 380,
#  "'yes": 381,
#  'important': 382,
#  'trembling': 383,
#  'living': 384,
#  'wire': 385,
#  'seraph': 386,
#  'harper': 387,
#  'israfel': 388,
#  'small': 389,
#  'anything': 390,
#  'growing': 391,
#  'miles': 392,
#  'go': 393,
#  'before': 394,
#  'sleep': 395,
#  '``': 396,
#  'wonder': 397,
#  'signals': 398,
#  'published': 399,
#  'about': 400,
#  'driven': 401,
#  'rain': 402,
#  'wet': 403,
#  'swollen': 404,
#  'rolls': 405,
#  'through': 406,
#  'ether': 407,
#  'sighs': 408,
#  'sight': 409,
#  'thine': 410,
#  'awake': 411,
#  'guess': 412,
#  'filled': 413,
#  'hardest': 414,
#  'hue': 415,
#  'friend': 416,
#  'or': 417,
#  'two': 418,
#  'resignedly': 419,
#  'beneath': 420,
#  'sky': 421,
#  'sunshine': 422,
#  'save': 423,
#  'soul': 424,
#  'uplifted': 425,
#  'crowd': 426,
#  'around': 427,
#  'path-': 428,
#  'everybody': 429,
#  'took': 430,
#  'proof': 431,
#  'silvery-silken': 432,
#  'veil': 433,
#  'failed': 434,
#  'force': 435,
#  'strait': 436,
#  'son': 437,
#  'can': 438,
#  'common': 439,
#  'money': 440,
#  'goes': 441,
#  'so': 442,
#  'fast': 443,
#  'star-dials': 444,
#  'pointed': 445,
#  'morn-': 446,
#  'roads': 447,
#  'diverged': 448,
#  'wood': 449,
#  'groping': 450,
#  'after': 451,
#  'jam': 452,
#  'beyond': 453,
#  'utterance': 454,
#  'human': 455,
#  'tongue': 456,
#  'reverence': 457,
#  'minute': 458,
#  'heard': 459,
#  'step': 460,
#  'went': 461,
#  "'just": 462,
#  'so-': 463,
#  'ought': 464,
#  'protection': 465,
#  'town': 466,
#  'settle': 467,
#  'hence': 468,
#  'nature': 469,
#  'first': 470,
#  'green': 471,
#  'gold': 472,
#  'thinks': 473,
#  'word': 474,
#  'well': 475,
#  'prove': 476,
#  'high': 477,
#  'girdle': 478,
#  'mark': 479,
#  'moon': 480,
#  'chill': 481,
#  'effect': 482,
#  'raspberries': 483,
#  'hew': 484,
#  'shape': 485,
#  'strange': 486,
#  'hands—': 487,
#  'groan': 488,
#  'mount': 489,
#  'yaanek': 490,
#  'roses': 491,
#  'grew': 492,
#  'enchanted': 493,
#  'garden': 494,
#  'making': 495,
#  'allowance': 496,
#  'due': 497,
#  'send': 498,
#  'attic': 499,
#  'know': 500,
#  'gentle': 501,
#  'lot': 502,
#  "'the": 503,
#  'rights': 504,
#  'harder': 505,
#  'doubt': 506,
#  'end': 507,
#  'holding': 508,
#  'none': 509,
#  'leaf': 510,
#  'lingered': 511,
#  'brown': 512,
#  'said-': 513,
#  "'what": 514,
#  'written': 515,
#  'sister': 516,
#  "'ve": 517,
#  "'why": 518,
#  'married': 519,
#  'flickers': 520,
#  'would': 521,
#  'evening': 522,
#  'walk-': 523,
#  'saved': 524,
#  'going': 525,
#  'how': 526,
#  'dark': 527,
#  'woe': 528,
#  'yet': 529,
#  'sublime': 530,
#  'promises': 531,
#  'keep': 532,
#  'legitimately': 533,
#  'demand': 534,
#  'italian': 535,
#  'tones': 536,
#  'murmured': 537,
#  'talked-of': 538,
#  'mystery': 539,
#  'birth': 540,
#  'gone': 541,
#  'eternal': 542,
#  'rest': 543,
#  "'d'you": 544,
#  'person': 545,
#  'related': 546,
#  'herself': 547,
#  "'then": 548,
#  'gained': 549,
#  'foothold': 550,
#  'pursued': 551,
#  'did': 552,
#  'life': 553,
#  'time': 554,
#  'below': 555,
#  'roared': 556,
#  'brook': 557,
#  'hidden': 558,
#  'turned': 559,
#  'mossy': 560,
#  'banks': 561,
#  'meandering': 562,
#  'paths': 563,
#  'extravagance': 564,
#  'been': 565,
#  'purified': 566,
#  'electric': 567,
#  'fire': 568,
#  'woods': 569,
#  'excitement': 570,
#  'over': 571,
#  'idol': 572,
#  'diamond': 573,
#  'grown': 574,
#  "'she": 575,
#  'worry': 576,
#  'stood': 577,
#  'strain': 578,
#  'flattered': 579,
#  'towns': 580,
#  'fighting': 581,
#  'stir': 582,
#  'joy': 583,
#  'breathing': 584,
#  'isles': 585,
#  'blest': 586,
#  'passionate': 587,
#  'such': 588,
#  'spirit': 589,
#  'fit': 590,
#  'angels': 591,
#  'tenanted': 592,
#  'i—': 593,
#  'hate': 594,
#  'west': 595,
#  'cast': 596,
#  'voice': 597,
#  'look': 598,
#  'stars': 599,
#  'leaves': 600,
#  'withering': 601,
#  'sere': 602,
#  'bird': 603,
#  'angelic': 604,
#  'gift': 605,
#  'seems': 606,
#  'helpless': 607,
#  'looked': 608,
#  'saddest': 609,
#  'city': 610,
#  'lane': 611,
#  'hen': 612,
#  'us-': 613,
#  "'t": 614,
#  'symbol': 615,
#  'token': 616,
#  '2o3': 617,
#  'stay': 618,
#  'lethean': 619,
#  'peace': 620,
#  'skies-': 621,
#  'seem': 622,
#  'quarry': 623,
#  'now': 624,
#  'storms': 625,
#  'fate': 626,
#  "o'ercast": 627,
#  'bank': 628,
#  'note': 629,
#  'fold': 630,
#  'often': 631,
#  'seen': 632,
#  'smell': 633,
#  'feathers': 634,
#  'heat': 635,
#  'constellations': 636,
#  'new': 637,
#  'fountains': 638,
#  'overflow': 639,
#  'winds': 640,
#  'wrought': 641,
#  'without': 642,
#  'breath': 643,
#  'storm': 644,
#  'am': 645,
#  'sure': 646,
#  'shoulders': 647,
#  'dragging': 648,
#  'yellow': 649,
#  'strands': 650,
#  'runs': 651,
#  'unbridled': 652,
#  'off': 653,
#  'course': 654,
#  'alas': 655,
#  'sinner': 656,
#  'sacrifice': 657,
#  'poetess': 658,
#  'wrote': 659,
#  'book': 660,
#  'verses': 661,
#  'spell': 662,
#  'furs': 663,
#  'sell': 664,
#  'sky-high': 665,
#  'both': 666,
#  'hands': 667,
#  'now-': 668,
#  'many': 669,
#  'thoughts': 670,
#  'entombed': 671,
#  'suppose': 672,
#  'deserves': 673,
#  'pity': 674,
#  'might': 675,
#  'liked': 676,
#  'best': 677,
#  'truth-': 678,
#  'virtue-': 679,
#  'humanity-': 680,
#  'everything': 681,
#  "'today": 682,
#  'terror': 683,
#  'spoke': 684,
#  'letting': 685,
#  'sink': 686,
#  'temptation': 687,
#  'bathe': 688,
#  'crystalline': 689,
#  'least': 690,
#  'help': 691,
#  'dig': 692,
#  'grave': 693,
#  'within': 694,
#  'dim': 695,
#  'revels': 696,
#  'bad': 697,
#  'whence': 698,
#  'drawn': 699,
#  'forth': 700,
#  'happy': 701,
#  'repining': 702,
#  'sulphurous': 703,
#  'currents': 704,
#  'run': 705,
#  'last': 706,
#  'ranged': 707,
#  'just': 708,
#  'fun': 709,
#  'gets': 710,
#  'bedeviled-': 711,
#  'dew': 712,
#  'night-time': 713,
#  'summer': 714,
#  'grass': 715,
#  'fulfilled': 716,
#  'your': 717,
#  "'going": 718,
#  'bright': 719,
#  'i-dea': 720,
#  'dear-eye': 721,
#  'replied': 722,
#  'ulalume': 723,
#  'drag': 724,
#  'man': 725,
#  'lifting': 726,
#  'forgot': 727,
#  'staid': 728,
#  'shelter': 729,
#  'swept': 730,
#  'heavens': 731,
#  'turning': 732,
#  'heel': 733,
#  'truth': 734,
#  'bed': 735,
#  'mistake': 736,
#  'foreign': 737,
#  'soft': 738,
#  'dissyllables-': 739,
#  "'we": 740,
#  'friends': 741,
#  'office': 742,
#  'illumine': 743,
#  'enkindle-': 744,
#  'scurf': 745,
#  'plants': 746,
#  'weary': 747,
#  'over-heated': 748,
#  "'m": 749,
#  'stark': 750,
#  'drew': 751,
#  'passport': 752,
#  'beloved': 753,
#  'heroes': 754,
#  'deathless': 755,
#  'souls': 756,
#  'roam': 757,
#  'heart': 758,
#  'sybilic': 759,
#  'splendor': 760,
#  'beaming': 761,
#  'throw': 762,
#  'bare': 763,
#  'legs': 764,
#  'forget': 765,
#  'lone': 766,
#  'skiff': 767,
#  'bells': 768,
#  'drowned': 769,
#  "'how": 770,
#  'neighbour': 771,
#  'why': 772,
#  'hear': 773,
#  "'ll": 774,
#  'threatener': 775,
#  'yawning': 776,
#  'lenses': 777,
#  'acquainted': 778,
#  'vault': 779,
#  'lost': 780,
#  'fine': 781,
#  'fibrils': 782,
#  'piercing': 783,
#  'little': 784,
#  'fur': 785,
#  'trade': 786,
#  'comfort': 787,
#  'sew': 788,
#  'bet': 789,
#  'huse': 790,
#  'cribber': 791,
#  'gnawed': 792,
#  'tamed': 793,
#  'primeval': 794,
#  'tin': 795,
#  'box': 796,
#  'cupboard': 797,
#  'shelf': 798,
#  'much': 799,
#  'concerned': 800,
#  'earnest': 801,
#  'woes': 802,
#  "'no": 803,
#  'fête': 804,
#  'to-day': 805,
#  'present': 806,
#  'pathway': 807,
#  'part': 808,
#  'horse': 809,
#  'queer': 810,
#  'tears': 811,
#  'dry': 812,
#  'indians': 813,
#  'myth': 814,
#  'chicamoztoc': 815,
#  'lair': 816,
#  'lion': 817,
#  'plan': 818,
#  'gaining': 819,
#  'wealth': 820,
#  'need': 821,
#  'endless': 822,
#  'talk-talk': 823,
#  'give': 824,
#  'undivided': 825,
#  'half-way': 826,
#  'fought': 827,
#  'battle': 828,
#  'journeyed-': 829,
#  'journeyed': 830,
#  'here-': 831,
#  'complain': 832,
#  'perhaps': 833,
#  'else': 834,
#  'remoteness': 835,
#  'defied': 836,
#  'breathe': 837,
#  'incense': 838,
#  'slumbering': 839,
#  'lightning': 840,
#  'scribble': 841,
#  'hardly': 842,
#  'melt': 843,
#  'start': 844,
#  'dormant': 845,
#  'tree': 846,
#  'gnaws': 847,
#  'stable': 848,
#  'ai': 849,
#  'looking': 850,
#  'orchid': 851,
#  'calypso': 852,
#  'crib': 853,
#  'slept': 854,
#  'in-': 855,
#  'born': 856,
#  'bear': 857,
#  'keeping': 858,
#  'anywhere': 859,
#  'watch': 860,
#  'fill': 861,
#  'beauty': 862,
#  'kitchen': 863,
#  'yourself': 864,
#  'chores': 865,
#  'boston': 866,
#  'people': 867,
#  'toffile': 868,
#  'braced': 869,
#  'against': 870,
#  'arctic': 871,
#  'pole': 872,
#  'outdoor': 873,
#  'work': 874,
#  'strung': 875,
#  'hair': 876,
#  'wo': 877,
#  'looks': 878,
#  'leave': 879,
#  'empty': 880,
#  'house': 881,
#  'hole': 882,
#  'somewhere': 883,
#  'chalk-pile': 884,
#  'what-': 885,
#  'journey': 886,
#  'field': 887,
#  'floor': 888,
#  'pit': 889,
#  'starks': 890,
#  'digged': 891,
#  'till': 892,
#  'caught': 893,
#  'wind': 894,
#  'opening': 895,
#  'covers': 896,
#  'years': 897,
#  "'hesperides": 898,
#  "'and": 899,
#  'purer': 900,
#  'oracle': 901,
#  'headshake': 902,
#  'governor': 903,
#  'proclaimed': 904,
#  'toward': 905,
#  'noon': 906,
#  'settled': 907,
#  'less': 908,
#  'stole': 909,
#  'goblet': 910,
#  'children': 911,
#  'playhouse': 912,
#  'empurpled': 913,
#  'vapors': 914,
#  'sitting': 915,
#  'dwelling': 916,
#  'origin': 917,
#  'family': 918,
#  'whole': 919,
#  'edition': 920,
#  'packing': 921,
#  'case': 922,
#  'lyre': 923,
#  'singing': 924,
#  'swift': 925,
#  'simply': 926,
#  'someone': 927,
#  'level': 928,
#  'waves': 929,
#  'changed': 930,
#  'liking': 931,
#  'room': 932,
#  'bones': 933,
#  'ultimate': 934,
#  'climes': 935,
#  'quickening': 936,
#  'skeleton': 937,
#  'still-': 938,
#  'sweetly': 939,
#  'scintillant': 940,
#  'hiss': 941,
#  'spray': 942,
#  'teased': 943,
#  'possessed': 944,
#  'accounts': 945,
#  'rural': 946,
#  'letter-box': 947,
#  'lajway': 948,
#  'weight': 949,
#  'age': 950,
#  'snows': 951,
#  "'if": 952,
#  'remember': 953,
#  'rightly': 954,
#  'sprung': 955,
#  'something': 956,
#  'men': 957,
#  'pocket': 958,
#  'oh': 959,
#  'never': 960,
#  'loom': 961,
#  'seraphic': 962,
#  'glancing': 963,
#  'eyes-': 964,
#  'upturned': 965,
#  'faces': 966,
#  'thousand': 967,
#  'paused': 968,
#  'rested': 969,
#  'sort': 970,
#  'hook': 971,
#  'mow': 972,
#  'wither': 973,
#  'mute': 974,
#  'these': 975,
#  'folks': 976,
#  'day': 977,
#  'given': 978,
#  'plain': 979,
#  'speaking': 980,
#  'voices': 981,
#  'melancholy': 982,
#  'waters': 983,
#  'lie': 984,
#  'tottering': 985,
#  'hinted': 986,
#  'boss': 987,
#  'hens': 988,
#  'arms': 989,
#  'knees': 990,
#  'tending': 991,
#  'furthest': 992,
#  'bodies': 993,
#  'berries': 994,
#  'passion': 995,
#  'tone': 996,
#  'prospect': 997,
#  'terminates-': 998,
#  'bill': 999,
#  ...}

# %%
# initializing the matrix/vector of transition probablities
poe_matrix = np.zeros((len(token_to_num_mapping),len(token_to_num_mapping)))
frost_matrix = np.zeros((len(token_to_num_mapping),len(token_to_num_mapping)))

poe_vector = np.zeros(len(token_to_num_mapping))
frost_vector = np.zeros(len(token_to_num_mapping))

# %%
for i, row in df_train_poe.iterrows():
    for j in range(len(row['lines_tokenized_num'])-1):
        poe_matrix[row['lines_tokenized_num'][j],row['lines_tokenized_num'][j+1]] +=1
        if j==0:
            poe_vector[row['lines_tokenized_num'][j]]+=1

for i, row in df_train_frost.iterrows():
    for j in range(len(row['lines_tokenized_num'])-1):
        frost_matrix[row['lines_tokenized_num'][j],row['lines_tokenized_num'][j+1]] +=1
        if j==0:
            frost_vector[row['lines_tokenized_num'][j]]+=1

# %%
count_i_poe = poe_matrix.sum(axis=1,keepdims=True)
count_i_frost = frost_matrix.sum(axis=1,keepdims=True)
poe_matrix= np.log((poe_matrix+1)/(count_i_poe+len(token_to_num_mapping)))
frost_matrix= np.log((frost_matrix+1)/(count_i_frost+len(token_to_num_mapping)))

# %%
poe_vector = np.log((poe_vector+1)/(len(df_train_poe)+len(token_to_num_mapping)))
frost_vector = np.log((frost_vector+1)/(len(df_train_frost)+len(token_to_num_mapping)))

# %%
frost_matrix
# Out:
# array([[-7.89394514, -5.49604987, -7.89394514, ..., -7.89394514,
#         -7.89394514, -7.89394514],
#        [-8.00269416, -8.00269416, -8.00269416, ..., -7.30954698,
#         -8.00269416, -8.00269416],
#        [-7.86633892, -7.86633892, -7.86633892, ..., -7.86633892,
#         -7.86633892, -7.86633892],
#        ...,
#        [-7.86672229, -7.86672229, -7.86672229, ..., -7.86672229,
#         -7.1735751 , -7.86672229],
#        [-7.86633892, -7.86633892, -7.86633892, ..., -7.86633892,
#         -7.86633892, -7.86633892],
#        [-7.86672229, -7.86672229, -7.86672229, ..., -7.86672229,
#         -7.86672229, -7.86672229]])

# %%
poe_matrix
# Out:
# array([[-7.87169266, -6.4853983 , -7.87169266, ..., -7.87169266,
#         -7.87169266, -7.87169266],
#        [-7.95822719, -7.95822719, -6.8596149 , ..., -7.95822719,
#         -7.95822719, -7.95822719],
#        [-7.8671055 , -7.8671055 , -7.8671055 , ..., -7.8671055 ,
#         -7.8671055 , -7.8671055 ],
#        ...,
#        [-7.86633892, -7.86633892, -7.86633892, ..., -7.86633892,
#         -7.86633892, -7.86633892],
#        [-7.86633892, -7.86633892, -7.86633892, ..., -7.86633892,
#         -7.86633892, -7.86633892],
#        [-7.86633892, -7.86633892, -7.86633892, ..., -7.86633892,
#         -7.86633892, -7.86633892]])

# %%
frost_vector
# Out:
# array([-6.41863679, -4.13285881, -8.21039626, ..., -8.21039626,
#        -8.21039626, -8.21039626])

# %%
poe_vector
# Out:
# array([-6.44667175, -4.59037376, -8.05610966, ..., -8.05610966,
#        -8.05610966, -8.05610966])

# %% [markdown]
# #### priori -> the initial state
#
# important if imbalanced class

# %%
# each class count at start - priori

prior_poe, prior_frost = len(df_train_poe)/len(df_train),len(df_train_frost)/len(df_train)
log_prior_poe, log_prior_frost = np.log(prior_poe),np.log(prior_frost)

# %%
prior_poe, prior_frost
# Out:
# (0.3372524752475248, 0.6627475247524752)

# %%
log_prior_poe, log_prior_frost
# Out:
# (-1.0869234444177964, -0.411361168633292)

# %%
A_poe = poe_matrix
Pi_poe = poe_vector

# %%
A_frost = frost_matrix
Pi_frost = frost_vector

# %%
def predict(input_):
    prob_poe = log_prior_poe
    prob_frost = log_prior_frost
    
    for i in range(len(input_)-1):
        try:
            if i==0:
                prob_poe+=Pi_poe[input_[i]]
                prob_frost+=Pi_frost[input_[i]]
            else:
                prob_poe+=A_poe[input_[i],input_[i+1]]
                prob_frost+=A_frost[input_[i],input_[i+1]]
        except:
            pass
    
    if prob_frost>prob_poe:
        return 'frost'
    else:
        return 'poe'

# %% [markdown]
# ### train set prediction

# %%
df_train.head()
# Out:
#                                             lines  label  \
# 0       for the resurrection of deep-buried faith    poe
# 1                          still more unfettered,  frost
# 2                  be nothing which thou art not.    poe
# 3               and in it a piano loudly playing.  frost
# 4  then he came at me with one hand outstretched,  frost
#
#                                      lines_tokenized  \
# 0   [for, the, resurrection, of, deep-buried, faith]
# 1                          [still, more, unfettered]
# 2               [be, nothing, which, thou, art, not]
# 3           [and, in, it, a, piano, loudly, playing]
# 4  [then, he, came, at, me, with, one, hand, outs...
#
#                     lines_tokenized_num
# 0                    [0, 1, 2, 3, 4, 5]
# 1                             [6, 7, 8]
# 2               [9, 10, 11, 12, 13, 14]
# 3          [15, 16, 17, 18, 19, 20, 21]
# 4  [22, 23, 24, 25, 26, 27, 28, 29, 30]

# %%
df_train['pred_label'] = df_train.lines_tokenized_num.apply(predict)

# %% [markdown]
# ### test set prediction

# %%
df_test['lines_tokenized'] = df_test.lines.apply(nltk.word_tokenize)
df_test.lines_tokenized = df_test.lines_tokenized.apply(lambda x:[i for i in x if i not in string.punctuation])
df_test['lines_tokenized_num'] = df_test.lines_tokenized.apply(token_num)

# %%
df_test['pred_label'] = df_test.lines_tokenized_num.apply(predict)

# %% [markdown]
# #### Accuracy measure - using f1 score
#
# Using f1 score - as the classes are imbalanced

# %%
def encode_category(cat):
    if cat=='frost':
        return 1
    if cat=='poe':
        return 0

# %% [markdown]
# #### accuracy train set

# %%
df_train.label = df_train.label.apply(encode_category)
df_train.pred_label = df_train.pred_label.apply(encode_category)

# %%
df_train.head()
# Out:
#                                             lines  label  \
# 0       for the resurrection of deep-buried faith      0
# 1                          still more unfettered,      1
# 2                  be nothing which thou art not.      0
# 3               and in it a piano loudly playing.      1
# 4  then he came at me with one hand outstretched,      1
#
#                                      lines_tokenized  \
# 0   [for, the, resurrection, of, deep-buried, faith]
# 1                          [still, more, unfettered]
# 2               [be, nothing, which, thou, art, not]
# 3           [and, in, it, a, piano, loudly, playing]
# 4  [then, he, came, at, me, with, one, hand, outs...
#
#                     lines_tokenized_num  pred_label
# 0                    [0, 1, 2, 3, 4, 5]           0
# 1                             [6, 7, 8]           1
# 2               [9, 10, 11, 12, 13, 14]           0
# 3          [15, 16, 17, 18, 19, 20, 21]           1
# 4  [22, 23, 24, 25, 26, 27, 28, 29, 30]           1

# %%
f1_score_train = f1_score(df_train.label,df_train.pred_label)
f1_score_train
# Out:
# 0.9907493061979649

# %%
confusion_matrix(df_train.label,df_train.pred_label)
# Out:
# array([[ 525,   20],
#        [   0, 1071]])

# %% [markdown]
# #### accuracy test set

# %%
df_test.label = df_test.label.apply(encode_category)
df_test.pred_label = df_test.pred_label.apply(encode_category)

# %%
df_test.head()
# Out:
#                                               lines  label  \
# 1473  she made a sudden movement toward her bodice,      1
# 1945          to live together and then pull apart.      1
# 951             of arthur amy's having once been up      1
# 532       (though once we had journeyed down here),      0
# 201         lying down to die, have suddenly arisen      0
#
#                                         lines_tokenized  \
# 1473  [she, made, a, sudden, movement, toward, her, ...
# 1945       [to, live, together, and, then, pull, apart]
# 951       [of, arthur, amy, 's, having, once, been, up]
# 532      [though, once, we, had, journeyed, down, here]
# 201      [lying, down, to, die, have, suddenly, arisen]
#
#                             lines_tokenized_num  pred_label
# 1473  [93, 374, 18, 2609, 2609, 905, 107, 2609]           1
# 1945         [74, 228, 354, 15, 22, 2609, 2609]           1
# 951     [3, 185, 186, 150, 1699, 144, 565, 211]           1
# 532          [232, 144, 78, 351, 830, 113, 229]           0
# 201      [1348, 113, 74, 1349, 263, 1350, 1351]           0

# %%
f1_score_test = f1_score(df_test.label,df_test.pred_label)
f1_score_test
# Out:
# 0.8880503144654088

# %%
confusion_matrix(df_test.label,df_test.pred_label)
# Out:
# array([[ 96,  77],
#        [ 12, 353]])

# %% [markdown]
# #### this turns out to be a bad classifier for the class which has lower number in  imbalanced class

# %% [markdown]
# #### Basic steps done:
#
# * files of each poets read
# * each line is considered 1 data row with label
# * train and test set split
# * now we will create as many markov model as number of classes
# * first tokenize each row of training set
# * convert tokens into integers -> unique word mapped to an index
# * now as required by any markov model ,we need
#     * matrix of transition probablities - Matrix `A` and Vector `Pi`
#     * Current State - That is basically here initial state if is imbalanced classes , so priori
# * instead of `probality+multiplication` , we used `log probablity+summation`
